# %%
#import models
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

from sklearn.ensemble import VotingClassifier

import pandas as pd 
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('heart.csv')

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     69    1   0       160   234    1        2      131      0      0.1
# 1     69    0   0       140   239    0        0      151      0      1.8
# 2     66    0   0       150   226    0        0      114      0      2.6
# 3     65    1   0       138   282    1        2      174      0      1.4
# 4     64    1   0       110   211    0        2      144      1      1.8
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 292   40    1   3       152   223    0        0      181      0      0.0
# 293   39    1   3       118   219    0        0      140      0      1.2
# 294   35    1   3       120   198    0        0      130      1      1.6
# 295   35    0   3       138   183    0        0      182      0      1.4
# 296   35    1   3       126   282    0        2      156      1      0.0
#
#      slope  ca  thal  condition
# 0        1   1     0          0
# ...

# %%
df.shape
# Out:
# (297, 14)

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   69    1   0       160   234    1        2      131      0      0.1      1
# 1   69    0   0       140   239    0        0      151      0      1.8      0
# 2   66    0   0       150   226    0        0      114      0      2.6      2
# 3   65    1   0       138   282    1        2      174      0      1.4      1
# 4   64    1   0       110   211    0        2      144      1      1.8      1
#
#    ca  thal  condition
# 0   1     0          0
# 1   2     0          0
# 2   0     0          0
# 3   1     0          1
# 4   0     0          0

# %%
df.shape
# Out:
# (297, 14)

# %%
df.shape[0]
# Out:
# 297

# %%
df.shape[1]
# Out:
# 14

# %%
rows = df.shape[0]
cols = df.shape[1]
print(rows, cols)
# Out:
# 297 14

# %%
import os 
os.listdir()
# Out:
# ['processed_cleveland_data3.csv',
#  'README.md',
#  'heart_random.ipynb',
#  'processed_cleveland_data2.csv',
#  'svm.ipynb',
#  'voting_ensemble1.ipynb',
#  'naivebayes.ipynb',
#  'heart.csv',
#  'cross_valid.ipynb',
#  '.git',
#  'heart_cleveland_upload.csv',
#  'heart_cleveland.ipynb',
#  'processed_cleveland1.csv']

# %%
x = df.drop('condition', axis=1)
y = df['condition']

# %%
x
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     69    1   0       160   234    1        2      131      0      0.1
# 1     69    0   0       140   239    0        0      151      0      1.8
# 2     66    0   0       150   226    0        0      114      0      2.6
# 3     65    1   0       138   282    1        2      174      0      1.4
# 4     64    1   0       110   211    0        2      144      1      1.8
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 292   40    1   3       152   223    0        0      181      0      0.0
# 293   39    1   3       118   219    0        0      140      0      1.2
# 294   35    1   3       120   198    0        0      130      1      1.6
# 295   35    0   3       138   183    0        0      182      0      1.4
# 296   35    1   3       126   282    0        2      156      1      0.0
#
#      slope  ca  thal
# 0        1   1     0
# 1        0   2     0
# 2        2   0     0
# ...

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      1
# 4      0
#       ..
# 292    1
# 293    1
# 294    1
# 295    0
# 296    1
# Name: condition, Length: 297, dtype: int64

# %%
for i in (0, 5, 7, 31, 47, 51, 58, 62, 66, 75, 86, 88, 126, 131,135, 141, 142, 162, 201, 243):
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=i)
    log_clf = LogisticRegression()
    rnd_clf = RandomForestClassifier()
    #svm_clf = SVC()
    #knn_clf = KNeighborsClassifier(n_neighbors=5)
    nbg_clf = GaussianNB()
    voting_clf = VotingClassifier(estimators=[('lr', log_clf), ('rf', rnd_clf),('nb', nbg_clf)], voting='hard')
    for clf in (log_clf, rnd_clf, nbg_clf, voting_clf):
        clf.fit(x_train, y_train)
        y_pred = clf.predict(x_test)
        print(i, clf.__class__.__name__, accuracy_score(y_test, y_pred))
    print()
# Out:
# 0 LogisticRegression 0.8533333333333334
# 0 RandomForestClassifier 0.84
# 0 GaussianNB 0.84
# 0 VotingClassifier 0.8533333333333334
#
# 5 LogisticRegression 0.8266666666666667
# 5 RandomForestClassifier 0.8533333333333334
# 5 GaussianNB 0.8533333333333334
# 5 VotingClassifier 0.8533333333333334
#
# 7 LogisticRegression 0.8933333333333333
# 7 RandomForestClassifier 0.8666666666666667
# 7 GaussianNB 0.8666666666666667
# 7 VotingClassifier 0.88
#
# 31 LogisticRegression 0.88
# 31 RandomForestClassifier 0.8666666666666667
# 31 GaussianNB 0.9333333333333333
# 31 VotingClassifier 0.8933333333333333
#
# 47 LogisticRegression 0.7866666666666666
# 47 RandomForestClassifier 0.7733333333333333
# 47 GaussianNB 0.8
# 47 VotingClassifier 0.8133333333333334
#
# 51 LogisticRegression 0.84
# 51 RandomForestClassifier 0.7866666666666666
# 51 GaussianNB 0.8133333333333334
# 51 VotingClassifier 0.8266666666666667
#
# 58 LogisticRegression 0.8533333333333334
# ...

# %%
voting_clf = VotingClassifier(estimators=[('lr', log_clf), ('rf', rnd_clf),('svc', svm_clf),('nb', nbg_clf)], voting='hard')

# %%
for clf in (log_clf, rnd_clf, nbg_clf, svm_clf, voting_clf):
    clf.fit(x_train, y_train)
    y_pred = clf.predict(x_test)
    print(clf.__class__.__name__, accuracy_score(y_test, y_pred))
# Out:
# LogisticRegression 0.881578947368421
# RandomForestClassifier 0.8289473684210527
# GaussianNB 0.881578947368421
# SVC 0.6973684210526315
# VotingClassifier 0.868421052631579
